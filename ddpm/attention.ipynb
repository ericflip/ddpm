# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nn import AttentionBlock
import torch

# %%
x = torch.ones((1, 64, 16, 16)).to("cuda")

# %%
attention = AttentionBlock(64).to("cuda")

# %%
attention(x)
# Out:
# torch.Size([1, 64, 16, 16])
# torch.Size([1, 64, 16, 16])
# tensor([[[[ 0.0341,  0.0341,  0.0341,  ...,  0.0341,  0.0341,  0.0341],
#           [ 0.0341,  0.0341,  0.0341,  ...,  0.0341,  0.0341,  0.0341],
#           [ 0.0341,  0.0341,  0.0341,  ...,  0.0341,  0.0341,  0.0341],
#           ...,
#           [ 0.0341,  0.0341,  0.0341,  ...,  0.0341,  0.0341,  0.0341],
#           [ 0.0341,  0.0341,  0.0341,  ...,  0.0341,  0.0341,  0.0341],
#           [ 0.0341,  0.0341,  0.0341,  ...,  0.0341,  0.0341,  0.0341]],
#
#          [[-0.0315, -0.0315, -0.0315,  ..., -0.0315, -0.0315, -0.0315],
#           [-0.0315, -0.0315, -0.0315,  ..., -0.0315, -0.0315, -0.0315],
#           [-0.0315, -0.0315, -0.0315,  ..., -0.0315, -0.0315, -0.0315],
#           ...,
#           [-0.0315, -0.0315, -0.0315,  ..., -0.0315, -0.0315, -0.0315],
#           [-0.0315, -0.0315, -0.0315,  ..., -0.0315, -0.0315, -0.0315],
#           [-0.0315, -0.0315, -0.0315,  ..., -0.0315, -0.0315, -0.0315]],
#
# ...
