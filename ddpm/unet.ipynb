# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from unet import UNet
import torch

# %%
x = torch.zeros((1, 3, 32, 32)).to("cuda")

# %%
unet = UNet(in_channels=3, model_channels=64, out_channels=1, num_res_blocks=1, attention_resolutions=(2, ), channel_mult=(1, 2, 4, 8)).to("cuda")
unet
# Out:
# [64, 64, 64, 128, 128, 256, 256, 512]
# 8
# UNet(
#   (time_embed): Sequential(
#     (0): Linear(in_features=64, out_features=256, bias=True)
#     (1): Swish()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (in_layer): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (downsamples): ModuleList(
#     (0): TimeSequential(
#       (layers): ModuleList(
#         (0): ResNetBlock(
#           (in_layers): Sequential(
#             (0): GroupNorm(32, 64, eps=1e-05, affine=True)
#             (1): Swish()
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (time_layers): Sequential(
#             (0): Swish()
#             (1): Linear(in_features=256, out_features=64, bias=True)
#           )
#           (out_layers): Sequential(
#             (0): GroupNorm(32, 64, eps=1e-05, affine=True)
#             (1): Swish()
#             (2): Dropout(p=0, inplace=False)
# ...

# %%
unet(x, torch.tensor([1]).to("cuda")).shape
# Out:
# [torch.Size([1, 64, 32, 32]), torch.Size([1, 64, 32, 32]), torch.Size([1, 64, 16, 16]), torch.Size([1, 128, 16, 16]), torch.Size([1, 128, 8, 8]), torch.Size([1, 256, 8, 8]), torch.Size([1, 256, 4, 4]), torch.Size([1, 512, 4, 4])]
# torch.Size([1, 512, 4, 4])
# torch.Size([1, 1, 32, 32])
# torch.Size([1, 1, 32, 32])
